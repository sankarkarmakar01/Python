# %%
print("Hello")
# Out:
# Hello

# %%
print(2)
# Out:
# 2

# %%
print(53.9)
# Out:
# 53.9

# %%
print("Sankar", "Karmakar")
# Out:
# Sankar Karmakar

# %%
print("Hello", "World", sep='-')
# Out:
# Hello-World

# %%
print("Sankar", "Karmakar", end=" ")
# Out:
# Sankar Karmakar
