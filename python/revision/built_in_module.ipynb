# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             _testcapi           getpass             pydevd_tracing
# __future__          _testclinic         gettext             pydoc
# __hello__           _testclinic_limited glob                pydoc_data
# __phello__          _testconsole        graphlib            pyexpat
# _abc                _testimportmultiple gzip                pygments
# _aix_support        _testinternalcapi   hashlib             queue
# _android_support    _testlimitedcapi    heapq               quopri
# _apple_support      _testmultiphase     hmac                random
# _ast                _testsinglephase    html                re
# _ast_unparse        _thread             http                reprlib
# _asyncio            _threading_local    idlelib             rlcompleter
# _bisect             _tkinter            imaplib             runfiles
# _blake2             _tokenize           importlib           runpy
# ...

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(5)
# Out:
# 120

# %%
math.ceil(6.3)
# Out:
# 7

# %%
import random

# %%
random.randint(1,100)
# Out:
# 91

# %%
a = [1,2,5,8,9]
random.shuffle(a)

# %%
a
# Out:
# [5, 1, 8, 2, 9]

# %%
import time

# %%
time.time()
# Out:
# 1775140671.6591167

# %%
time.ctime()
# Out:
# 'Thu Apr  2 20:08:02 2026'

# %%
print("Hello")
time.sleep(3)
print("World")
# Out:
# Hello
# World

# %%
import os
os.getcwd()
# Out:
# 'D:\\Program\\Python\\python\\revision'

# %%
os.listdir()
# Out:
# ['01_print.ipynb',
#  '02_datatype.ipynb',
#  '03_variables.ipynb',
#  '04_keywords.ipynb',
#  '05_user_input.ipynb',
#  'built_in_module.ipynb',
#  'others.ipynb']
