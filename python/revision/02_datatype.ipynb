# %%
a = 10589551655656565654656444454

# %%
a
# Out:
# 10589551655656565654656444454

# %%
i = 1e309

# %%
i
# Out:
# inf

# %%
i = 1e308

# %%
i
# Out:
# 1e+308

# %%
f = 2.33

# %%
f
# Out:
# 2.33

# %%
f = 1.7e309

# %%
f
# Out:
# inf

# %%
f = 1.7e308

# %%
f
# Out:
# 1.7e+308

# %%
b = True

# %%
b
# Out:
# True

# %%
c = 4 + 9j

# %%
c
# Out:
# (4+9j)

# %%
s = "Sankar"

# %%
s
# Out:
# 'Sankar'

# %%
#list
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuples
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5,8,1,2})
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
#dict
print({
    "name":"Sankar",
    "age":21,
    "gender":"male"
})
# Out:
# {'name': 'Sankar', 'age': 21, 'gender': 'male'}
