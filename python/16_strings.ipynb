# %%
name = "Sankar"

# %%
name = 'Sankar'

# %%
name = """Sankar"""

# %%
name = "Sankar Karmakar"

# %%
len(name)
# Out:
# 15

# %%
name[1:5]
# Out:
# 'anka'

# %%
name[0:3]
# Out:
# 'San'

# %%
name[2:]
# Out:
# 'nkar Karmakar'

# %%
name[:7]
# Out:
# 'Sankar '

# %%
name[-8:-1]
# Out:
# 'Karmaka'

# %%
name[-5:]
# Out:
# 'makar'

# %%
name[:-5]
# Out:
# 'Sankar Kar'

# %%
name[0:]
# Out:
# 'Sankar Karmakar'

# %%
name[:0]
# Out:
# ''

# %%
name[:len(name)]
# Out:
# 'Sankar Karmakar'

# %%
name[:]
# Out:
# 'Sankar Karmakar'

# %%
name[1:6:2]
# Out:
# 'akr'

# %%
num = "0123456789"

# %%
num[1:6:2]
# Out:
# '135'

# %% [markdown]
# Functions

# %%
len(name)
# Out:
# 15

# %%
name.endswith("kar")
# Out:
# True

# %%
name.startswith("Sa")
# Out:
# True

# %%
name.startswith("ar")
# Out:
# False

# %%
name.capitalize()
# Out:
# 'Sankar karmakar'

# %%
name.upper()
# Out:
# 'SANKAR KARMAKAR'

# %%
l = name.lower()
l
# Out:
# 'sankar karmakar'

# %%
name.title()
# Out:
# 'Sankar Karmakar'

# %%
l.capitalize()
# Out:
# 'Sankar karmakar'

# %%
text = "    Hello   "
print(text)
print(text.strip())
# Out:
#     Hello
# Hello

# %%
text.lstrip()
# Out:
# 'Hello   '

# %%
text.rstrip()
# Out:
# '    Hello'

# %%
text = "I am a good boy."

# %%
text.replace("good","bad")
# Out:
# 'I am a bad boy.'

# %%
text.split()
# Out:
# ['I', 'am', 'a', 'good', 'boy.']

# %%
text.split(",")
# Out:
# ['I am a good boy.']

# %%
text.split(".")
# Out:
# ['I am a good boy', '']

# %%
text.split(" ")
# Out:
# ['I', 'am', 'a', 'good', 'boy.']

# %%
words = ['I', 'am', 'a', 'good', 'boy.']

# %%
print(" ".join(words))
# Out:
# I am a good boy.

# %%
text = "Sankar"

# %%
text.find("S")
# Out:
# 0

# %%
text.count("a")
# Out:
# 2

# %%
text.isalpha()
# Out:
# True

# %%
text.isdigit()
# Out:
# False

# %%
text.isnumeric()
# Out:
# False

# %%
text.isalnum()
# Out:
# True
