# %%
print("Hello, Welcome to my cursed world...")
# Out:
# Hello, Welcome to my cursed world...

# %%
print("Hi, Python")
# Out:
# Hi, Python

# %%
print('Hello Python')
# Out:
# Hello Python

# %%
# print("Hello')

# %%
print("-------------------")
print("------Python-------")
print("-------------------")
# Out:
# -------------------
# ------Python-------
# -------------------

# %%
# print("Hi "Python"")
print("Hi \"Python\"")
# Out:
# Hi "Python"

# %%
print('Hi "Python"')
# Out:
# Hi "Python"

# %%
print("Hi \'Python\'")
# Out:
# Hi 'Python'

# %%
print("Path: C:\\Users\\Sankar")
# Out:
# Path: C:\Users\Sankar

# %%
print("Hello\nWelcome to this world")
# Out:
# Hello
# Welcome to this world

# %%
print("Hello,\tWelcome to this world")
# Out:
# Hello,	Welcome to this world

# %%
# Challenge
print("Your Learning Path:\n\t- Python Basics\n\t- Data Engineering\n\t- AI")
# Out:
# Your Learning Path:
# 	- Python Basics
# 	- Data Engineering
# 	- AI

# %%
print("""
Your Learning Path:
	- Python Basics
	- Data Engineering
	- AI
""")
# Out:
# Your Learning Path:
# 	- Python Basics
# 	- Data Engineering
# 	- AI
