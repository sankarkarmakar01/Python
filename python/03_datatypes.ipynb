# %%
a = "Sankar"
print(a)
# Out:
# Sankar

# %%
a = 10
print(a)
# Out:
# 10

# %%
a = 20.569
print(a)
# Out:
# 20.569

# %%
a = 52 + 63j
print(a)
# Out:
# (52+63j)

# %%
a = [1,2,3,5,'Sankar',True]
print(a)
# Out:
# [1, 2, 3, 5, 'Sankar', True]

# %%
a = (1,2,3,5,'Sankar',True)
print(a)
# Out:
# (1, 2, 3, 5, 'Sankar', True)

# %%
a = range(10)
print(a)
# Out:
# range(0, 10)

# %%
a = {"name" : "Sankar", "age" : 21}
print(a)
# Out:
# {'name': 'Sankar', 'age': 21}

# %%
a = {1,2,5,9,2,6,4,1}
print(a)
# Out:
# {1, 2, 4, 5, 6, 9}

# %%
a = frozenset({1,2,5,9,2,6,4,1})
print(a)
# Out:
# frozenset({1, 2, 4, 5, 6, 9})

# %%
a = True
print(a)
# Out:
# True

# %%
a = b"Sankar" # bytes
print(a)
# Out:
# b'Sankar'

# %%
a = bytearray(5)
print(a)
# Out:
# bytearray(b'\x00\x00\x00\x00\x00')

# %%
a = memoryview(bytes(5))
print(a)

# %%
a = None
print(a)
# Out:
# None
