# %%
t = (1, 2, 3, 2, 2)

# %%
print(t)
# Out:
# (1, 2, 3, 2, 2)

# %%
print(t.count(2))
# Out:
# 3

# %%
t = (10, 20, 30, 20)
print(t.index(20))
# Out:
# 1

# %%
t = (5, 2, 9, 1)

# %%
print(len(t))
# Out:
# 4

# %%
print(max(t))
# Out:
# 9

# %%
print(min(t))
# Out:
# 1

# %%
print(sum(t))
# Out:
# 17

# %%
print(sorted(t))   # returned a list
# Out:
# [1, 2, 5, 9]

# %%
print(t[0])
print(t[1:3])  # (20, 30)
# Out:
# 5
# (2, 9)

# %%
t1 = (1, 2)
t2 = (3, 4)
print(t1 + t2)
# Out:
# (1, 2, 3, 4)

# %%
print((1, 2) * 3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
print(2 in (1, 2, 3))
# Out:
# True

# %%
for item in (1, 2, 3):
    print(item)
# Out:
# 1
# 2
# 3

# %%
# Packing
t = (10, 20, 30)
print(t)
# Out:
# (10, 20, 30)

# %%
# Unpacking
a, b, c = t
print(a, b, c)
# Out:
# 10 20 30
