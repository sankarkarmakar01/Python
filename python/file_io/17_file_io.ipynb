# %%
from os import linesep

f = open("file.txt","r")
data = f.read()
print(data)
f.close()
# Out:
# You are amazing 2

# %%
st = "\nYou are amazing"
f = open("file.txt",'w')
f.write(st)
f.close()

# %%
f = open("file.txt")
lines = f.readlines()
print(lines, type(lines))
f.close()
# Out:
# ['hello\n', 'sankar'] <class 'list'>

# %%
f = open("file.txt")

line = f.readline()
while line != "":
    print(line)
    line = f.readline()
f.close()
# Out:
# hello
#
# sankar

# %%
f = open("file.txt","a")
f.write("Hey")
f.close()

# %%
# f = open("file.txt")
with open("file.txt") as f:
    print(f.read())
# Out:
# hello
# sankarHeyHeyHeyHeyHeyHeyHeyHeyHeyHeyHeyHeyHey
