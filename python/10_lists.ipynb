# %%
list1 = [1, 2, 3, 4, 5]

# %%
list2 = [10, 12]

# %%
print(list1)
# Out:
# [100, 1, 2, 3, 4, 5]

# %%
list1.append(6)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6, 10, 12]

# %%
list1.insert(0, 100)
print(list1)
# Out:
# [100, 1, 2, 3, 4, 5, 6, 10, 12]

# %%
list1.remove(12)
print(list1)
# Out:
# [100, 1, 2, 3, 4, 5, 6, 10]

# %%
list1.pop()
print(list1)
# Out:
# [100, 1, 2, 3, 4, 5, 6]

# %%
p_item = list1.pop()
print(p_item)
# Out:
# 6

# %%
list2.clear()
print(list2)
# Out:
# []

# %%
print(list1.index(2))
print(list1.index(100, 0))
print(list1.index(5))
# Out:
# 2
# 0
# 5

# %%
list1.append(1)
print("Count: ", list1.count(1))
# Out:
# Count:  2

# %%
print("List: ", list1)
list1.sort()
print("Sort List: ", list1)
# Out:
# List:  [100, 1, 2, 3, 4, 5, 1]
# Sort List:  [1, 1, 2, 3, 4, 5, 100]

# %%
list1.sort(key = int, reverse = True)
print("Sort List reverse: ", list1)
# Out:
# Sort List reverse:  [100, 5, 4, 3, 2, 1, 1]

# %%
list1.reverse()
print("Reverse List: ", list1)
# Out:
# Reverse List:  [100, 5, 4, 3, 2, 1, 1]

# %%
print("List: ", list1)
list3 = list1.copy()
print("Copy List: ", list3)
# Out:
# List:  [100, 5, 4, 3, 2, 1, 1]
# Copy List:  [100, 5, 4, 3, 2, 1, 1]

# %%
print(len(list1))
# Out:
# 7

# %%
print(min(list1))
# Out:
# 1

# %%
print(max(list1))
# Out:
# 100

# %%
print(sum(list1))
# Out:
# 116

# %%
print(sorted(list1))
# Out:
# [1, 1, 2, 3, 4, 5, 100]

# %%
new_list = [1, 2, 3]
print(new_list[1:3])
print(new_list * 3)
print(1 in new_list)
print(100 not in new_list)
# Out:
# [2, 3]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# True
# True

# %%
for i in new_list:
    print(i)
# Out:
# 1
# 2
# 3
