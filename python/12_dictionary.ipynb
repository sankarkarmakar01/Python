# %%
student = {
    "name": "Sankar",
    "age": 21,
    "course": "Python"
}

# %%
print("Original Dictionary:", student)
# Out:
# Original Dictionary: {'name': 'Sankar', 'age': 21, 'course': 'Python'}

# %%
# get() → Safe access
print("Name:", student.get("name"))
print("Marks (default):", student.get("marks", "Not Available"))
# Out:
# Name: Sankar
# Marks (default): Not Available

# %%
# keys() → All keys
print("Keys:", student.keys())
# Out:
# Keys: dict_keys(['name', 'age', 'course'])

# %%
# values() → All values
print("Values:", student.values())
# Out:
# Values: dict_values(['Sankar', 21, 'Python'])

# %%
# items() → Key-value pairs
print("Items:", student.items())
# Out:
# Items: dict_items([('name', 'Sankar'), ('age', 21), ('course', 'Python')])

# %%
# Add new key using assignment
student["marks"] = 85
print("After adding marks:", student)
# Out:
# After adding marks: {'name': 'Sankar', 'age': 21, 'course': 'Python', 'marks': 85}

# %%
# update() → Add / update multiple items
student.update({"age": 22, "city": "Delhi"})
print("After update:", student)
# Out:
# After update: {'name': 'Sankar', 'age': 22, 'course': 'Python', 'marks': 85, 'city': 'Delhi'}

# %%
# setdefault() → Get value, add if missing
student.setdefault("grade", "A")
print("After setdefault:", student)
# Out:
# After setdefault: {'name': 'Sankar', 'age': 22, 'course': 'Python', 'marks': 85, 'city': 'Delhi', 'grade': 'A'}

# %%
# pop() → Remove specific key
removed_value = student.pop("city")
print("Removed city:", removed_value)
print("After pop:", student)
# Out:
# Removed city: Delhi
# After pop: {'name': 'Sankar', 'age': 22, 'course': 'Python', 'marks': 85, 'grade': 'A'}

# %%
# popitem() → Remove last inserted item
last_item = student.popitem()
print("Removed last item:", last_item)
print("After popitem:", student)
# Out:
# Removed last item: ('grade', 'A')
# After popitem: {'name': 'Sankar', 'age': 22, 'course': 'Python', 'marks': 85}

# %%
# copy() → Copy dictionary
student_copy = student.copy()
print("Copied dictionary:", student_copy)
# Out:
# Copied dictionary: {'name': 'Sankar', 'age': 22, 'course': 'Python', 'marks': 85}

# %%
# len() → Number of items
print("Length:", len(student))
# Out:
# Length: 4

# %%
# sorted() → Sort keys
print("Sorted keys:", sorted(student))
# Out:
# Sorted keys: ['age', 'course', 'marks', 'name']

# %%
# max() & min() → Based on keys
print("Max key:", max(student))
print("Min key:", min(student))
# Out:
# Max key: name
# Min key: age

# %%
# clear() → Remove all items
student.clear()
print("After clear:", student)
# Out:
# After clear: {}

# %%
# fromkeys() → Create new dictionary
subjects = ["Math", "Science", "English"]
# mark = [10,20,30]
marks = dict.fromkeys(subjects, 0)
print("Dictionary from fromkeys:", marks)
# Out:
# Dictionary from fromkeys: {'Math': 0, 'Science': 0, 'English': 0}
